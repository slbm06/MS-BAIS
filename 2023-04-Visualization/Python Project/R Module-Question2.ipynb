# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_excel('Combined.xlsx',sheet_name='Pasco')

# %%
df.columns = ['Date', 'Daily Number', 'Moving Average']

# %%
df
# Out:
#           Date  Daily Number  Moving Average
# 0   2020-03-01             2             2.0
# 1   2020-03-02             1             1.5
# 2   2020-03-07             2             1.7
# 3   2020-03-08             3             2.0
# 4   2020-03-09             5             2.6
# ..         ...           ...             ...
# 362 2021-03-02            60            88.8
# 363 2021-03-03            64            81.8
# 364 2021-03-04            47            72.0
# 365 2021-03-05            29            65.3
# 366 2021-03-06            64            61.3
#
# [367 rows x 3 columns]

# %%
plot_title='COVID Daily Numbers and Moving Average for Pasco County'
df.plot('Date', ['Daily Number', 'Moving Average'],xlabel='',ylim=[0,400], title=plot_title)
# Out:
# <AxesSubplot:title={'center':'COVID Daily Numbers and Moving Average for Pasco County'}>
