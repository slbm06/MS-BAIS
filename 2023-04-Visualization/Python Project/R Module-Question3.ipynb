# %%
import pandas as pd

# %%
df = pd.read_excel('Combined.xlsx',sheet_name='Hillsborough')

# %%
df.columns = ['Date', 'Daily Number', 'Moving Average']

# %%
df
# Out:
#               Date  Daily Number  Moving Average
# 0    March 1, 2020             2        2.000000
# 1    March 3, 2020             2        2.000000
# 2    March 4, 2020             1        1.666667
# 3    March 5, 2020             3        2.000000
# 4    March 6, 2020             3        2.200000
# ..             ...           ...             ...
# 365  March 2, 2021           134      292.750000
# 366  March 3, 2021           298      264.500000
# 367  March 4, 2021           271      251.500000
# 368  March 5, 2021           241      241.500000
# 369  March 6, 2021           263      243.375000
#
# [370 rows x 3 columns]

# %%
plot_title='COVID Daily Case Numbers and Moving Average for Hillsborough Country'

axes = df.plot('Date','Daily Number', color='purple',kind='line')

df.plot('Date', 'Moving Average', kind='bar',xticks=[], width=1, ax=axes, title=plot_title)
# Out:
# <AxesSubplot:title={'center':'COVID Daily Case Numbers and Moving Average for Hillsborough Country'}, xlabel='Date'>
