# %% [markdown]
# # Tutorial - Sentiment Analysis - imdb

# %%
import pandas as pd
import numpy as np

# %%
imdb = pd.read_csv('movie.csv')

# %%
imdb.head(5)
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %% [markdown]
# ## Change the target variable to ordinal
#
# This is a multi-class classification problem. There are three categories we will predict:<br>
# Whether a post is "graphics," "hockey," or "medical" related
#
# #### Keras doesn't like text-based target values. So, we have to change it to "ordinal" values. Though, this is only needed to convert each category to an integer value.

# %%
#Convert the target to ordinal to avoid text 
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()

imdb['target'] = enc.fit_transform(imdb[['label']])

# %%
imdb.head()
# Out:
#                                                 text  label  target
# 0  I grew up (b. 1965) watching and loving the Th...      0     0.0
# 1  When I put this movie in my DVD player, and sa...      0     0.0
# 2  Why do people who do not know what a particula...      0     0.0
# 3  Even though I have great interest in Biblical ...      0     0.0
# 4  Im a die hard Dads Army fan and nothing will e...      1     1.0

# %%
target = imdb['target']

# %% [markdown]
# ## Assign the "text" (input) variable

# %%
# Check for missing values

imdb[['text']].isna().sum()
# Out:
# text    0
# dtype: int64

# %%
# If there were missing values:
# imdb['text'].fillna('missing', inplace=True)

# %%
input_data = imdb['text']

# %% [markdown]
# ## Split the data

# %%
from sklearn.model_selection import train_test_split

train_set, test_set, train_y, test_y = train_test_split(input_data, target, test_size=0.3, random_state=42)

# %%
train_set.shape, train_y.shape
# Out:
# ((28000,), (28000,))

# %%
test_set.shape, test_y.shape
# Out:
# ((12000,), (12000,))

# %% [markdown]
# ## Keras: Tokenizer
#
# In order to use Keras, you first need to install tensorflow. You can start the Anaconda Prompt and enter the following to do so: `pip install tensorflow`
#
# Keras Tokenizer works a little different than scikit-learn (but the idea is the same)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

keras_tokenizer = Tokenizer(num_words=2000, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True)
# Only looking at most important 2,000 "words"/columns

keras_tokenizer.fit_on_texts(train_set)  # similar to fit_transform()
# Out:
# 2023-10-22 15:31:19.657747: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-22 15:31:19.683994: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-22 15:31:20.234573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# After identifying the terms to be used in the term-by-document matrix, 
# create the matrix using one of the below using tfidf

train_binary_matrix = keras_tokenizer.texts_to_matrix(train_set, mode='tfidf')
train_binary_matrix.shape
# Out:
# (28000, 2000)

# %%
# Now we need to perform the test data set

test_binary_matrix = keras_tokenizer.texts_to_matrix(test_set, mode='tfidf')
test_binary_matrix.shape
# Out:
# (12000, 2000)

# %%
train_binary_matrix
# Out:
# array([[0.        , 1.94633466, 0.7100851 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.18041367, 1.85292298, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 2.22901331, 1.85292298, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 2.88314801, 1.85292298, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 3.17585807, 2.4127948 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.46309232, 1.49019332, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# Tokenizer's attributes:

print(keras_tokenizer.word_index) # shows the indeces -- will include the first 2000 columns
# Out:
# {'the': 1, 'and': 2, 'a': 3, 'of': 4, 'to': 5, 'is': 6, 'br': 7, 'in': 8, 'it': 9, 'i': 10, 'this': 11, 'that': 12, 'was': 13, 'as': 14, 'for': 15, 'movie': 16, 'with': 17, 'but': 18, 'film': 19, 'on': 20, 'not': 21, 'you': 22, 'are': 23, 'his': 24, 'have': 25, 'be': 26, 'one': 27, 'he': 28, 'at': 29, 'all': 30, 'by': 31, 'an': 32, 'they': 33, 'from': 34, 'so': 35, 'who': 36, 'like': 37, 'or': 38, 'just': 39, 'her': 40, 'about': 41, 'out': 42, 'if': 43, "it's": 44, 'has': 45, 'there': 46, 'some': 47, 'what': 48, 'good': 49, 'more': 50, 'very': 51, 'when': 52, 'up': 53, 'no': 54, 'my': 55, 'time': 56, 'even': 57, 'would': 58, 'she': 59, 'really': 60, 'which': 61, 'only': 62, 'see': 63, 'story': 64, 'their': 65, 'had': 66, 'can': 67, 'me': 68, 'were': 69, 'well': 70, 'than': 71, 'we': 72, 'much': 73, 'been': 74, 'bad': 75, 'get': 76, 'other': 77, 'great': 78, 'will': 79, 'do': 80, 'also': 81, 'into': 82, 'because': 83, 'him': 84, 'people': 85, 'how': 86, 'first': 87, 'most': 88, "don't": 89, 'them': 90, 'made': 91, 'then': 92, 'make': 93, 'its': 94, 'movies': 95, 'way': 96, 'too': 97, 'could': 98, 'any': 99, 'after': 100, 'think': 101, 'characters': 102, 'watch': 103, 'films': 104, 'two': 105, 'seen': 106, 'character': 107, 'many': 108, 'being': 109, 'never': 110, 'plot': 111, 'love': 112, 'life': 113, 'acting': 114, 'did': 115, 'little': 116, 'where': 117, 'know': 118, 'show': 119, 'over': 120, 'best': 121, 'ever': 122, 'off': 123, 'does': 124, 'better': 125, 'your': 126, 'end': 127, 'man': 128, 'still': 129, 'scene': 130, 'say': 131, 'these': 132, 'here': 133, 'while': 134, 'why': 135, 'scenes': 136, 'such': 137, 'go': 138, 'something': 139, 'through': 140, 'back': 141, 'should': 142, 'those': 143, 'real': 144, "i'm": 145, 'now': 146, 'watching': 147, 'thing': 148, 'actors': 149, "didn't": 150, "doesn't": 151, 'though': 152, '10': 153, 'years': 154, 'funny': 155, 'actually': 156, 'another': 157, 'work': 158, 'old': 159, 'before': 160, 'look': 161, 'makes': 162, 'nothing': 163, 'director': 164, 'find': 165, 'same': 166, 'going': 167, 'new': 168, 'lot': 169, 'again': 170, 'every': 171, 'part': 172, 'few': 173, 'down': 174, 'things': 175, 'us': 176, 'cast': 177, 'pretty': 178, 'quite': 179, 'want': 180, 'world': 181, 'horror': 182, 'young': 183, 'seems': 184, 'around': 185, "can't": 186, 'however': 187, 'thought': 188, 'take': 189, 'big': 190, 'fact': 191, 'enough': 192, 'got': 193, 'long': 194, 'give': 195, 'both': 196, "that's": 197, 'series': 198, 'may': 199, 'between': 200, 'music': 201, "i've": 202, 'right': 203, 'own': 204, 'saw': 205, 'comedy': 206, 'must': 207, 'without': 208, 'role': 209, 'action': 210, 'guy': 211, "isn't": 212, 'done': 213, 'almost': 214, 'times': 215, 'interesting': 216, 'always': 217, 'gets': 218, 'whole': 219, 'original': 220, "there's": 221, 'come': 222, 'least': 223, 'point': 224, 'far': 225, 'bit': 226, 'script': 227, 'feel': 228, 'might': 229, '2': 230, 'am': 231, 'anything': 232, 'minutes': 233, 'probably': 234, "he's": 235, 'making': 236, 'last': 237, 'family': 238, 'since': 239, 'tv': 240, 'performance': 241, 'kind': 242, 'yet': 243, 'away': 244, 'worst': 245, 'fun': 246, 'rather': 247, 'girl': 248, 'anyone': 249, 'sure': 250, 'hard': 251, 'found': 252, 'each': 253, 'played': 254, 'especially': 255, 'woman': 256, 'day': 257, 'although': 258, 'our': 259, 'screen': 260, 'looking': 261, 'dvd': 262, 'course': 263, 'having': 264, 'trying': 265, 'comes': 266, 'believe': 267, 'ending': 268, 'everything': 269, 'set': 270, 'goes': 271, 'worth': 272, 'maybe': 273, 'shows': 274, 'sense': 275, 'put': 276, 'book': 277, 'american': 278, 'once': 279, 'main': 280, 'place': 281, 'different': 282, 'three': 283, 'reason': 284, 'actor': 285, 'looks': 286, 'true': 287, 'watched': 288, 'effects': 289, "wasn't": 290, 'war': 291, 'play': 292, 'half': 293, 'someone': 294, 'during': 295, 'plays': 296, 'money': 297, 'job': 298, 'instead': 299, 'together': 300, '1': 301, 'year': 302, 'said': 303, 'seeing': 304, 'takes':  ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 

from sklearn.metrics import accuracy_score

# %%
rnd_clf = RandomForestClassifier(n_estimators=300, n_jobs=-1) 

rnd_clf.fit(train_binary_matrix, train_y)
# Out:
# RandomForestClassifier(n_estimators=300, n_jobs=-1)

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import accuracy_score

# %%
#Train accuracy

train_y_pred = rnd_clf.predict(train_binary_matrix)

train_acc = accuracy_score(train_y, train_y_pred)

print('Train acc: {}' .format(train_acc))
# Out:
# Train acc: 1.0

# %%
#Test accuracy

test_y_pred = rnd_clf.predict(test_binary_matrix)

test_acc = accuracy_score(test_y, test_y_pred)

print('Test acc: {}' .format(test_acc))
# Out:
# Test acc: 0.849

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

#Usually created on test set
confusion_matrix(test_y, test_y_pred)
# Out:
# array([[5022,  942],
#        [ 870, 5166]])

# %% [markdown]
# ## Stochastic Gradient Descent Classifier

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(max_iter=150, tol=1e-3)

# %%
sgd_clf.fit(train_binary_matrix, train_y)
# Out:
# SGDClassifier(max_iter=150)

# %% [markdown]
# ## Accuracy

# %%
#Train accuracy

train_y_pred = sgd_clf.predict(train_binary_matrix)

train_acc = accuracy_score(train_y, train_y_pred)

print('Train acc: {}' .format(train_acc))
# Out:
# Train acc: 0.8956785714285714

# %%
#Test accuracy

test_y_pred = sgd_clf.predict(test_binary_matrix)

test_acc = accuracy_score(test_y, test_y_pred)

print('Test acc: {}' .format(test_acc))
# Out:
# Test acc: 0.8611666666666666

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

#Usually created on test set
confusion_matrix(test_y, test_y_pred)
# Out:
# array([[4902, 1062],
#        [ 604, 5432]])
