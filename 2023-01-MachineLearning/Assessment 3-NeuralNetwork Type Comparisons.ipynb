# %% [markdown]
# # Unit 3 Assessment

# %% [markdown]
# In this assignment, we will focus on healthcare. This data set is made available by MIT. It contains data about 9,026 heartbeat measurements. Each row represents a single measurement (captured on a timeline). There are a total of 80 data points (columns). This is a multiclass classification task: predict whether the measurement represents a normal heartbeat or other anomalies.

# %% [markdown]
# ## Description of Variables
#
# You will use the **hearbeat_cleaned.csv** data set for this assignment. Each row represents a single measurement. Columns labeled as T1 from T80 are the time steps on the timeline (there are 80 time steps, each time step has only one measurement).
#
# The last column is the target variable. It shows the label (category) of the measurement as follows:<br>
# 0 = Normal<br>
# 1 = Supraventricular premature beat<br>
# 2 = Premature ventricular contraction<br>
# 3 = Fusion of ventricular and normal beat<br>
# 4 = Unclassifiable beat

# %% [markdown]
# ## Goal
#
# Use the data set **hearbeat_cleaned.csv** to predict the column called **Target**. The input variables are columns labeled as **T1 to T80**.

# %% [markdown]
# ## Submission:
#
# Please save and submit this Jupyter notebook file. The correctness of the code matters for your grade. **Readability and organization of your code is also important.** You may lose points for submitting unreadable/undecipherable code. Therefore, use markdown cells to create sections, and use comments where necessary.

# %% [markdown]
# # Read and Prepare the Data (1 points)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
hbeat = pd.read_csv("heartbeat_cleaned.csv")

# %%
hbeat.shape
# Out:
# (7960, 81)

# %%
hbeat.head()
# Out:
#       T1     T2     T3      T4      T5      T6      T7      T8      T9  \
# 0  0.987  0.892  0.461  0.1130  0.1490  0.1900  0.1650  0.1620  0.1470
# 1  1.000  0.918  0.621  0.1330  0.1050  0.1250  0.1170  0.0898  0.0703
# 2  1.000  0.751  0.143  0.1040  0.0961  0.0519  0.0442  0.0416  0.0364
# 3  1.000  0.740  0.235  0.0464  0.0722  0.0567  0.0103  0.0155  0.0284
# 4  1.000  0.833  0.309  0.0191  0.1010  0.1200  0.1040  0.0874  0.0765
#
#       T10  ...     T72     T73     T74     T75    T76     T77     T78    T79  \
# 0  0.1380  ...  0.1970  0.1970  0.1960  0.2030  0.201  0.1990  0.2010  0.205
# 1  0.0781  ...  0.1950  0.1910  0.1520  0.1720  0.207  0.2110  0.2070  0.207
# 2  0.0857  ...  0.2260  0.2420  0.2440  0.2860  0.468  0.8160  0.9770  0.452
# 3  0.0155  ...  0.0851  0.0747  0.0515  0.0593  0.067  0.0361  0.1210  0.451
# 4  0.0765  ...  0.2050  0.4210  0.8030  0.9510  0.467  0.0000  0.0519  0.082
#
#       T80  Target
# 0  0.2080       0
# 1  0.1720       0
# 2  0.0519       0
# 3  0.8690       0
# 4  0.0628       0
#
# [5 rows x 81 columns]

# %%
y = hbeat['Target']
x = hbeat.drop('Target', axis=1)

# %%
y.unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.3)

# %%
#Target variables need to be an array with integer type
train_y = np.array(train_y)
test_y = np.array(test_y)

# Set the target values are set to be integers
train_y = train_y.astype(np.int32)
test_y = test_y.astype(np.int32)

# %%
train_y[0:30]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 0, 2, 0, 4, 0, 4, 4, 0, 0, 0, 0, 0, 2, 0, 0,
#        2, 0, 4, 2, 0, 0, 4, 2])

# %%
#Convert input variables to a 2-D array with float data type
train_x= np.array(train_x)
test_x= np.array(test_x)

train_x = train_x.astype(np.float32)
test_x = test_x.astype(np.float32)

# %%
train_x.shape
# Out:
# (5572, 80)

# %%
train_x
# Out:
# array([[1.    , 0.875 , 0.22  , ..., 0.327 , 0.329 , 0.324 ],
#        [0.997 , 0.943 , 0.413 , ..., 0.306 , 0.297 , 0.304 ],
#        [0.835 , 0.615 , 0.396 , ..., 0.282 , 0.311 , 0.286 ],
#        ...,
#        [1.    , 0.833 , 0.3   , ..., 0.851 , 0.426 , 0.0235],
#        [0.954 , 0.971 , 0.464 , ..., 0.151 , 0.167 , 0.192 ],
#        [0.825 , 0.447 , 0.45  , ..., 0.314 , 0.325 , 0.314 ]],
#       dtype=float32)

# %%
train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1], 1))
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], 1))

# %%
train_x.shape, train_y.shape
# Out:
# ((5572, 80, 1), (5572,))

# %%
train_x
# Out:
# array([[[1.    ],
#         [0.875 ],
#         [0.22  ],
#         ...,
#         [0.327 ],
#         [0.329 ],
#         [0.324 ]],
#
#        [[0.997 ],
#         [0.943 ],
#         [0.413 ],
#         ...,
#         [0.306 ],
#         [0.297 ],
#         [0.304 ]],
#
#        [[0.835 ],
#         [0.615 ],
#         [0.396 ],
#         ...,
#         [0.282 ],
#         [0.311 ],
#         [0.286 ]],
#
#        ...,
#
#        [[1.    ],
#         [0.833 ],
#         [0.3   ],
#         ...,
#         [0.851 ],
#         [0.426 ],
#         [0.0235]],
#
#        [[0.954 ],
#         [0.971 ],
#         [0.464 ],
#         ...,
#         [0.151 ],
#         [0.167 ],
#         [0.192 ]],
#
#        [[0.825 ],
#         [0.447 ],
#         [0.45  ],
#         ...,
#         [0.314 ],
#         [0.325 ],
#         [0.314 ]]], dtype=float32)

# %% [markdown]
# # Find the baseline (0.5 point)

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy="most_frequent")

dummy_clf.fit(train_x, train_y)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
from sklearn.metrics import accuracy_score
dummy_train_pred = dummy_clf.predict(train_x)

baseline_train_acc = accuracy_score(train_y, dummy_train_pred)

print('Baseline Train Accuracy: {}' .format(baseline_train_acc))
# Out:
# Baseline Train Accuracy: 0.5838119167264896

# %%
dummy_test_pred = dummy_clf.predict(test_x)

baseline_test_acc = accuracy_score(test_y, dummy_test_pred)

print('Baseline Test Accuracy: {}' .format(baseline_test_acc))
# Out:
# Baseline Test Accuracy: 0.5778894472361809

# %% [markdown]
# # Build a cross-sectional (i.e., a regular) Neural Network model using Keras (with only one hidden layer) (2 points)

# %%
model = keras.models.Sequential([

    keras.layers.Flatten(input_shape=[80, 1]),
    keras.layers.Dense(80, activation='relu'),
    keras.layers.Dense(5, activation='softmax')      
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=30, validation_data=(test_x, test_y))
# Out:
# Epoch 1/30
# 175/175 [==============================] - 1s 2ms/step - loss: 0.6728 - accuracy: 0.7789 - val_loss: 0.5849 - val_accuracy: 0.8162
# Epoch 2/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.4329 - accuracy: 0.8591 - val_loss: 0.5226 - val_accuracy: 0.8057
# Epoch 3/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3679 - accuracy: 0.8851 - val_loss: 0.3511 - val_accuracy: 0.9037
# Epoch 4/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.3218 - accuracy: 0.9079 - val_loss: 0.4036 - val_accuracy: 0.8911
# Epoch 5/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.3069 - accuracy: 0.9092 - val_loss: 0.4451 - val_accuracy: 0.8325
# Epoch 6/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2944 - accuracy: 0.9099 - val_loss: 0.3054 - val_accuracy: 0.9200
# Epoch 7/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.9151 - val_loss: 0.3512 - val_accuracy: 0.8936
# Epoch 8/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2742 - accuracy: 0.9178 - val_loss: 0.3435 - val_accuracy: 0.9062
# Epoch 9/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.9239 - val_loss: 0.3029 - val_accuracy: 0.9083
# Epoch 10/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2489 - accuracy: 0.9253 - val_loss: 0.6409 - val_accuracy: 0.7144
# Epoch 11/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.9225 - val_loss: 0.3107 - val_accuracy: 0.9095
# Epoch 12/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2384 - accuracy: 0.9277 - val_loss: 0.2834 - val_accuracy: 0.9209
# Epoch 13/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9252 - val_loss: 0.3130 - val_accuracy: 0.9079
# Epoch 14/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2271 - accuracy: 0.9302 - val_loss: 0.3225 - val_accuracy: 0.9041
# Epoch 15/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2199 - accuracy: 0.9336 - val_loss: 0.3110 - val_accuracy: 0.9158
# Epoch 16/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2156 - accuracy: 0.9368 - val_loss: 0.2883 - val_accuracy: 0.9200
# Epoch 17/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2127 - accuracy: 0.9327 - val_loss: 0.2730 - val_accuracy: 0.9255
# Epoch 18/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2083 - accuracy: 0.9327 - val_loss: 0.2566 - val_accuracy: 0.9276
# Epoch 19/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2091 - accuracy: 0.9341 - val_loss: 0.2524 - val_accuracy: 0.9326
# Epoch 20/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2020 - accuracy: 0.9388 - val_loss: 0.3894 - val_accuracy: 0.8894
# Epoch 21/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9309 - val_loss: 0.2682 - val_accuracy: 0.9280
# Epoch 22/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1978 - accuracy: 0.9408 - val_loss: 0.6024 - val_accuracy: 0.7391
# Epoch 23/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2014 - accuracy: 0.9372 - val_loss: 0.2569 - val_accuracy: 0.9280
# Epoch 24/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1870 - accuracy: 0.9419 - val_loss: 0.3117 - val_accuracy: 0.9200
# Epoch 25/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.9424 - val_loss: 0.2887 - val_accuracy: 0.9267
# Epoch 26/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1786 - accuracy: 0.9454 - val_loss: 0.2628 - val_accuracy: 0.9330
# Epoch 27/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1895 - accuracy: 0.9417 - val_loss: 0.2715 - val_accuracy: 0.9229
# Epoch 28/30
# 175/175 [==============================] - 0s 1ms/step - loss: 0.1788 - accuracy: 0.9454 - val_loss: 0.2592 - val_accuracy: 0.9301
# Epoch 29/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1790 - accuracy: 0.9453 - val_loss: 0.2842 - val_accuracy: 0.9217
# Epoch 30/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1802 - accuracy: 0.9447 - val_loss: 0.2720 - val_accuracy: 0.9271

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# Huge improvement over the baseline
# Out:
# loss: 0.27
# accuracy: 92.71%

# %% [markdown]
# # Build a deep cross-sectional (i.e., regular) Neural Network model using Keras (with two or more hidden layers) (2 points)

# %%
model = keras.models.Sequential([

    keras.layers.Flatten(input_shape=[80, 1]),
    keras.layers.Dense(60, activation='relu'),
    keras.layers.Dense(40, activation='relu'),
    keras.layers.Dense(20, activation='relu'),
    keras.layers.Dense(5, activation='softmax')      
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=30, validation_data=(test_x, test_y))
# Out:
# Epoch 1/30
# 175/175 [==============================] - 2s 3ms/step - loss: 0.6093 - accuracy: 0.7938 - val_loss: 0.5286 - val_accuracy: 0.8476
# Epoch 2/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4117 - accuracy: 0.8638 - val_loss: 0.5531 - val_accuracy: 0.8011
# Epoch 3/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8909 - val_loss: 0.3508 - val_accuracy: 0.8974
# Epoch 4/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3075 - accuracy: 0.9063 - val_loss: 0.7360 - val_accuracy: 0.7965
# Epoch 5/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.8878 - val_loss: 0.5129 - val_accuracy: 0.8275
# Epoch 6/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3439 - accuracy: 0.8896 - val_loss: 0.3002 - val_accuracy: 0.9125
# Epoch 7/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2816 - accuracy: 0.9083 - val_loss: 0.3659 - val_accuracy: 0.8798
# Epoch 8/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9153 - val_loss: 0.2851 - val_accuracy: 0.9192
# Epoch 9/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9252 - val_loss: 0.2725 - val_accuracy: 0.9242
# Epoch 10/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.9241 - val_loss: 0.3692 - val_accuracy: 0.8966
# Epoch 11/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9280 - val_loss: 0.3327 - val_accuracy: 0.8987
# Epoch 12/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9248 - val_loss: 0.2647 - val_accuracy: 0.9255
# Epoch 13/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 0.9302 - val_loss: 0.3305 - val_accuracy: 0.8949
# Epoch 14/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2288 - accuracy: 0.9282 - val_loss: 0.2894 - val_accuracy: 0.9158
# Epoch 15/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9320 - val_loss: 0.2727 - val_accuracy: 0.9162
# Epoch 16/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9313 - val_loss: 0.2549 - val_accuracy: 0.9276
# Epoch 17/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2005 - accuracy: 0.9374 - val_loss: 0.2645 - val_accuracy: 0.9246
# Epoch 18/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2098 - accuracy: 0.9318 - val_loss: 0.2295 - val_accuracy: 0.9334
# Epoch 19/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.9358 - val_loss: 0.2488 - val_accuracy: 0.9343
# Epoch 20/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1937 - accuracy: 0.9392 - val_loss: 0.2529 - val_accuracy: 0.9296
# Epoch 21/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9415 - val_loss: 0.2597 - val_accuracy: 0.9284
# Epoch 22/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.9375 - val_loss: 0.4110 - val_accuracy: 0.8769
# Epoch 23/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2119 - accuracy: 0.9352 - val_loss: 0.2469 - val_accuracy: 0.9301
# Epoch 24/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1887 - accuracy: 0.9390 - val_loss: 0.2615 - val_accuracy: 0.9301
# Epoch 25/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1835 - accuracy: 0.9415 - val_loss: 0.2340 - val_accuracy: 0.9410
# Epoch 26/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9469 - val_loss: 0.3272 - val_accuracy: 0.9154
# Epoch 27/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1838 - accuracy: 0.9426 - val_loss: 0.2360 - val_accuracy: 0.9368
# Epoch 28/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9451 - val_loss: 0.2444 - val_accuracy: 0.9363
# Epoch 29/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9444 - val_loss: 0.2434 - val_accuracy: 0.9435
# Epoch 30/30
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1777 - accuracy: 0.9435 - val_loss: 0.2414 - val_accuracy: 0.9389

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.24
# accuracy: 93.89%

# %% [markdown]
# # Build a LSTM Model (with only one layer) (2 points)

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')
callback = [earlystop]

# %%
n_steps = 80
n_inputs = 1

model = keras.models.Sequential([
    
    keras.layers.LSTM(40, input_shape=[n_steps, n_inputs]),
    keras.layers.Dense(5, activation='softmax')
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, validation_data = (test_x, test_y), callbacks=callback)
# Out:
# Epoch 1/20
# 175/175 [==============================] - 6s 23ms/step - loss: 1.1174 - accuracy: 0.5791 - val_loss: 1.0818 - val_accuracy: 0.5779
# Epoch 2/20
# 175/175 [==============================] - 4s 22ms/step - loss: 1.0553 - accuracy: 0.5888 - val_loss: 1.0325 - val_accuracy: 0.6273
# Epoch 3/20
# 175/175 [==============================] - 4s 22ms/step - loss: 1.0098 - accuracy: 0.6028 - val_loss: 1.0171 - val_accuracy: 0.5976
# Epoch 4/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.8752 - accuracy: 0.6606 - val_loss: 0.7598 - val_accuracy: 0.7282
# Epoch 5/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.7846 - accuracy: 0.7215 - val_loss: 0.7817 - val_accuracy: 0.7425
# Epoch 6/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.7082 - accuracy: 0.7699 - val_loss: 0.8240 - val_accuracy: 0.7064
# Epoch 7/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.5503 - accuracy: 0.8270 - val_loss: 0.5291 - val_accuracy: 0.8371
# Epoch 8/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.4805 - accuracy: 0.8480 - val_loss: 0.5043 - val_accuracy: 0.8425
# Epoch 9/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.4300 - accuracy: 0.8676 - val_loss: 0.4614 - val_accuracy: 0.8530
# Epoch 10/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.4059 - accuracy: 0.8758 - val_loss: 0.4226 - val_accuracy: 0.8781
# Epoch 11/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3921 - accuracy: 0.8805 - val_loss: 0.4777 - val_accuracy: 0.8463
# Epoch 12/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3772 - accuracy: 0.8853 - val_loss: 0.3627 - val_accuracy: 0.8945
# Epoch 13/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3620 - accuracy: 0.8911 - val_loss: 0.3675 - val_accuracy: 0.8899
# Epoch 14/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3570 - accuracy: 0.8923 - val_loss: 0.4397 - val_accuracy: 0.8593
# Epoch 15/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3458 - accuracy: 0.8977 - val_loss: 0.3746 - val_accuracy: 0.8924
# Epoch 16/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3253 - accuracy: 0.9025 - val_loss: 0.3255 - val_accuracy: 0.9066
# Epoch 17/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3262 - accuracy: 0.9011 - val_loss: 0.3191 - val_accuracy: 0.9083
# Epoch 18/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3176 - accuracy: 0.9040 - val_loss: 0.3617 - val_accuracy: 0.8932
# Epoch 19/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3126 - accuracy: 0.9070 - val_loss: 0.3078 - val_accuracy: 0.9125
# Epoch 20/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3087 - accuracy: 0.9103 - val_loss: 0.3466 - val_accuracy: 0.8936

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.35
# accuracy: 89.36%

# %% [markdown]
# # Build a deep LSTM Model (with only two layers) (2 points)

# %%
n_steps = 80
n_inputs = 1

model = keras.models.Sequential([
    keras.layers.LSTM(60, return_sequences=True, input_shape=[n_steps, n_inputs]),
    keras.layers.LSTM(40, return_sequences=True),
    keras.layers.LSTM(20),
    keras.layers.Dense(5, activation='softmax')
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, validation_data = (test_x, test_y), callbacks=callback)
# Out:
# Epoch 1/20
# 175/175 [==============================] - 18s 74ms/step - loss: 1.1411 - accuracy: 0.5797 - val_loss: 1.1419 - val_accuracy: 0.5779
# Epoch 2/20
# 175/175 [==============================] - 12s 68ms/step - loss: 1.1250 - accuracy: 0.5838 - val_loss: 1.1516 - val_accuracy: 0.5779
# Epoch 3/20
# 175/175 [==============================] - 12s 68ms/step - loss: 1.1267 - accuracy: 0.5838 - val_loss: 1.1510 - val_accuracy: 0.5779
# Epoch 4/20
# 175/175 [==============================] - 12s 68ms/step - loss: 1.1246 - accuracy: 0.5838 - val_loss: 1.1521 - val_accuracy: 0.5779
# Epoch 5/20
# 175/175 [==============================] - 12s 67ms/step - loss: 1.1235 - accuracy: 0.5838 - val_loss: 1.1417 - val_accuracy: 0.5779
# Epoch 6/20
# 175/175 [==============================] - 12s 69ms/step - loss: 1.1228 - accuracy: 0.5838 - val_loss: 1.1466 - val_accuracy: 0.5779
# Epoch 7/20
# 175/175 [==============================] - 12s 69ms/step - loss: 1.1242 - accuracy: 0.5838 - val_loss: 1.1383 - val_accuracy: 0.5779
# Epoch 8/20
# 175/175 [==============================] - 12s 67ms/step - loss: 1.0533 - accuracy: 0.5829 - val_loss: 1.0711 - val_accuracy: 0.5779
# Epoch 9/20
# 175/175 [==============================] - 12s 69ms/step - loss: 1.0367 - accuracy: 0.5838 - val_loss: 1.0705 - val_accuracy: 0.5779
# Epoch 10/20
# 175/175 [==============================] - 12s 68ms/step - loss: 1.1153 - accuracy: 0.5835 - val_loss: 1.1415 - val_accuracy: 0.5779
# Epoch 11/20
# 175/175 [==============================] - 12s 69ms/step - loss: 1.1240 - accuracy: 0.5838 - val_loss: 1.1457 - val_accuracy: 0.5779
# Epoch 12/20
# 175/175 [==============================] - 12s 69ms/step - loss: 1.1351 - accuracy: 0.5743 - val_loss: 1.1403 - val_accuracy: 0.5779
# Epoch 13/20
# 175/175 [==============================] - 12s 67ms/step - loss: 1.1203 - accuracy: 0.5838 - val_loss: 1.1502 - val_accuracy: 0.5779
# Epoch 14/20
# 175/175 [==============================] - 12s 70ms/step - loss: 1.1216 - accuracy: 0.5838 - val_loss: 1.1418 - val_accuracy: 0.5779
# Epoch 14: early stopping

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 1.14
# accuracy: 57.79%

# %% [markdown]
# # Build a GRU Model (with only one layer) (2 points)

# %%
n_steps = 80
n_inputs = 1

model = keras.models.Sequential([
    keras.layers.GRU(40, input_shape=[n_steps, n_inputs]),
    keras.layers.Dense(5, activation='softmax')
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, validation_data = (test_x, test_y), callbacks=callback)
# Out:
# Epoch 1/20
# 175/175 [==============================] - 6s 24ms/step - loss: 1.0923 - accuracy: 0.5940 - val_loss: 1.0355 - val_accuracy: 0.5955
# Epoch 2/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.7813 - accuracy: 0.7181 - val_loss: 0.5258 - val_accuracy: 0.8095
# Epoch 3/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.4916 - accuracy: 0.8403 - val_loss: 0.4631 - val_accuracy: 0.8472
# Epoch 4/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.4080 - accuracy: 0.8699 - val_loss: 0.3699 - val_accuracy: 0.8911
# Epoch 5/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3644 - accuracy: 0.8911 - val_loss: 0.4145 - val_accuracy: 0.8727
# Epoch 6/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3588 - accuracy: 0.8887 - val_loss: 0.3115 - val_accuracy: 0.9116
# Epoch 7/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3188 - accuracy: 0.9033 - val_loss: 0.3253 - val_accuracy: 0.8982
# Epoch 8/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2948 - accuracy: 0.9078 - val_loss: 0.3058 - val_accuracy: 0.9079
# Epoch 9/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2857 - accuracy: 0.9106 - val_loss: 0.3122 - val_accuracy: 0.9020
# Epoch 10/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2707 - accuracy: 0.9164 - val_loss: 0.3562 - val_accuracy: 0.8844
# Epoch 11/20
# 175/175 [==============================] - 4s 20ms/step - loss: 0.3056 - accuracy: 0.9040 - val_loss: 0.4075 - val_accuracy: 0.8798
# Epoch 12/20
# 175/175 [==============================] - 4s 20ms/step - loss: 0.2953 - accuracy: 0.9121 - val_loss: 0.2974 - val_accuracy: 0.9125
# Epoch 13/20
# 175/175 [==============================] - 4s 20ms/step - loss: 0.2698 - accuracy: 0.9156 - val_loss: 0.4606 - val_accuracy: 0.8610
# Epoch 14/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.3313 - accuracy: 0.8932 - val_loss: 0.3859 - val_accuracy: 0.8534
# Epoch 15/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2675 - accuracy: 0.9155 - val_loss: 0.2988 - val_accuracy: 0.9162
# Epoch 16/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2491 - accuracy: 0.9228 - val_loss: 0.2718 - val_accuracy: 0.9217
# Epoch 17/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2314 - accuracy: 0.9289 - val_loss: 0.2625 - val_accuracy: 0.9192
# Epoch 18/20
# 175/175 [==============================] - 4s 22ms/step - loss: 0.2303 - accuracy: 0.9293 - val_loss: 0.2700 - val_accuracy: 0.9221
# Epoch 19/20
# 175/175 [==============================] - 4s 20ms/step - loss: 0.2306 - accuracy: 0.9293 - val_loss: 0.2368 - val_accuracy: 0.9296
# Epoch 20/20
# 175/175 [==============================] - 4s 21ms/step - loss: 0.2068 - accuracy: 0.9374 - val_loss: 0.2886 - val_accuracy: 0.9121

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.29
# accuracy: 91.21%

# %% [markdown]
# # Build a deep GRU Model (with only two layers) (2 points)

# %%
n_steps = 80
n_inputs = 1

model = keras.models.Sequential([
    keras.layers.GRU(60, return_sequences=True, input_shape=[n_steps, n_inputs]),
    keras.layers.GRU(40, return_sequences=True),
    keras.layers.GRU(20),
    keras.layers.Dense(5, activation='softmax')
])

# %%
np.random.seed(42)
tf.random.set_seed(42)

optimizer = keras.optimizers.Nadam(learning_rate=0.01)

model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=20, validation_data = (test_x, test_y), callbacks=callback)
# Out:
# Epoch 1/20
# 175/175 [==============================] - 18s 74ms/step - loss: 0.9711 - accuracy: 0.6427 - val_loss: 0.6789 - val_accuracy: 0.7647
# Epoch 2/20
# 175/175 [==============================] - 12s 71ms/step - loss: 0.5452 - accuracy: 0.8137 - val_loss: 0.4787 - val_accuracy: 0.8346
# Epoch 3/20
# 175/175 [==============================] - 12s 71ms/step - loss: 0.4293 - accuracy: 0.8519 - val_loss: 0.4702 - val_accuracy: 0.8358
# Epoch 4/20
# 175/175 [==============================] - 12s 69ms/step - loss: 0.3809 - accuracy: 0.8740 - val_loss: 0.5165 - val_accuracy: 0.8174
# Epoch 5/20
# 175/175 [==============================] - 12s 67ms/step - loss: 0.3529 - accuracy: 0.8871 - val_loss: 0.4063 - val_accuracy: 0.8673
# Epoch 6/20
# 175/175 [==============================] - 12s 67ms/step - loss: 0.3459 - accuracy: 0.8805 - val_loss: 0.3664 - val_accuracy: 0.8811
# Epoch 7/20
# 175/175 [==============================] - 12s 68ms/step - loss: 0.3367 - accuracy: 0.8889 - val_loss: 0.3219 - val_accuracy: 0.9058
# Epoch 8/20
# 175/175 [==============================] - 12s 69ms/step - loss: 0.3057 - accuracy: 0.9047 - val_loss: 0.3196 - val_accuracy: 0.9100
# Epoch 9/20
# 175/175 [==============================] - 12s 70ms/step - loss: 0.3157 - accuracy: 0.8979 - val_loss: 0.3461 - val_accuracy: 0.8861
# Epoch 10/20
# 175/175 [==============================] - 13s 72ms/step - loss: 0.2935 - accuracy: 0.9076 - val_loss: 0.3243 - val_accuracy: 0.9045
# Epoch 11/20
# 175/175 [==============================] - 12s 70ms/step - loss: 0.2954 - accuracy: 0.9060 - val_loss: 0.3449 - val_accuracy: 0.8987
# Epoch 12/20
# 175/175 [==============================] - 12s 68ms/step - loss: 0.2939 - accuracy: 0.9090 - val_loss: 0.2842 - val_accuracy: 0.9217
# Epoch 13/20
# 175/175 [==============================] - 12s 70ms/step - loss: 0.2666 - accuracy: 0.9203 - val_loss: 0.3473 - val_accuracy: 0.8928
# Epoch 14/20
# 175/175 [==============================] - 13s 74ms/step - loss: 0.2675 - accuracy: 0.9130 - val_loss: 0.3733 - val_accuracy: 0.8807
# Epoch 15/20
# 175/175 [==============================] - 13s 72ms/step - loss: 0.2746 - accuracy: 0.9104 - val_loss: 0.3134 - val_accuracy: 0.9075
# Epoch 16/20
# 175/175 [==============================] - 13s 74ms/step - loss: 0.2764 - accuracy: 0.9078 - val_loss: 0.4769 - val_accuracy: 0.8472
# Epoch 17/20
# 175/175 [==============================] - 13s 76ms/step - loss: 0.2845 - accuracy: 0.9083 - val_loss: 0.2853 - val_accuracy: 0.9229
# Epoch 17: early stopping

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print("%s: %.2f" % (model.metrics_names[0], scores[0]))
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# loss: 0.29
# accuracy: 92.29%

# %% [markdown]
# # Discussion

# %% [markdown]
# ## List the test values of each model you built (0.5 points)

# %% [raw]
# Baseline	57.78
# NN	        92.71
# Deep NN	    93.89 *****
# LSTM	    89.36
# Deep LSTM	57.79
# GRU      	91.21
# Deep GRU	92.29

# %% [markdown]
# ## Which model performs the best and why? (0.5 points)

# %% [raw]
# The best performing model is the Deep NN, followed closely by the regular NN, Deep GRU, and regular GRU.
#
# This seems to say that the order of the heart measurements does not affect the diagnostics:
# 0 = Normal
# 1 = Supraventricular premature beat
# 2 = Premature ventricular contraction
# 3 = Fusion of ventricular and normal beat
# 4 = Unclassifiable beat

# %% [markdown]
# ## How does it compare to baseline? (0.5 points)

# %% [raw]
# Most models beat the baseline handily.  Deep LSTM is the main exception there.  This may be because the relative short-term memory of the LSTM cells was not enough (GRU perform better) and seem to retain worse information that when no sequence is taken into accounts (Regular NN).  GRU looks at the importance of the information it retains and that seems to have been helpful here.
